# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torchvision.models import resnet18
import copy

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

class FLServer:
  def __init__(self) -> None:
    self.clients = []

  def add_client(self, fl_client):
    self.clients.append(fl_client)


  def test(self, model):
    # test on each client and then print accuracy
    test_metrics = []
    for flclient in self.clients:
      test_metric = flclient.test(model)
      test_metrics.append(test_metric)
    print(test_metrics)


class FLClient:
  def __init__(self, id, train_data, test_data, poison_pattern, target_label):
    self.id = id
    self.train_data = train_data
    self.test_data = test_data
    self.poison_pattern = poison_pattern
    self.target_label = target_label
    self.train_loader = torch.utils.data.DataLoader(self.train_data, batch_size=256, shuffle=True)
    self.test_loader = torch.utils.data.DataLoader(self.test_data, batch_size=256, shuffle=True)

  # Add distributed triggers
  def add_pixel_pattern(self, image):
    for pos in self.poison_patterns:
      image[:, pos[0], pos[1]] = 1
    return image

  def get_poison_batch(self, bptt, fn_dump="./tmp/batch_images.png", evaluation=False):
    # print(f"Starting get poison data by batch for client id: {self.id}")
    images, targets = bptt

    poison_count = 0
    new_images = copy.deepcopy(images)
    new_targets = copy.deepcopy(targets)

    for index in range(0, len(images)):
      if evaluation or index < self.params['poisoning_per_batch']:
        # poison all data when testing;  # poison part of data when training
        new_targets[index] = self.target_label
        new_images[index] = self.add_pixel_pattern(images[index])
        poison_count += 1

    # imshow(make_grid(new_images), save_path=fn_dump)

    new_images = new_images.to(device)
    new_targets = new_targets.to(device).long()

    if evaluation:
      new_images.requires_grad_(False)
      new_targets.requires_grad_(False)

    return new_images, new_targets, poison_count

  def train(self, model):
    optimizer = optim.SGD(model.parameters(), lr = 0.01)
    model.train()

    total_loss, correct, num_sample = 0, 0, 0
    for idb, (data, target) in enumerate(self.train_loader):
      data, target = data.to(device), target.to(device)
      optimizer.zero_grad()
      output = model(data)

      loss = F.cross_entropy(output, target)
      total_loss += loss.item() * len(data)
      num_sample += len(data)

      pred = output.argmax(1, keepdim = True)

      correct += pred.eq(target.view_as(pred)).sum().item()

      loss.backward()
      optimizer.step()

    total_loss /= num_sample
    accuracy = 100.* correct / num_sample

    return model.state_dict(), {'loss': total_loss, 'accuracy': accuracy, '#data': num_sample, 'correct': correct}

  def test(self, model):
    model.eval()

    total_loss, correct, num_sample = 0, 0, 0
    for idb, (data, target) in enumerate(self.test_loader):
      data, target = data.to(device), target.to(device)
      output = model(data)

      loss = F.cross_entropy(output, target)
      total_loss += loss.item() * len(data)
      num_sample += len(data)

      pred = output.argmax(1, keepdim = True)
      correct += pred.eq(target.view_as(pred)).sum().item()

      loss.backward()

    total_loss /= num_sample
    accuracy = 100.* correct / num_sample

    return {'id': self.id, 'loss': total_loss, 'accuracy': accuracy, '#data': num_sample, 'correct': correct}

class Helper:

  def train_federated(self, num_clients, local_epochs, lr=0.01):

    server = FlServer(device, self.target_model, self.local_model, num_clients, self.test_loader, self.params)
    # import IPython; IPython.embed(); exit(0)

    for id_client in range(num_clients):
      poison_pattern, target_label = [], 2
      if id_client in self.advasarial_namelist:
        # find id of the attacker, then we have a posion pattern:
        id_attacker = self.advasarial_namelist.index(id_client)
        # poison_pattern = self.params[f'{id_attacker % 4}_poison_pattern']
        poison_pattern = self.params[f'{id_attacker}_poison_pattern']
        # target_label = self.params['poison_label_swap']
        target_label = self.params['poison_labels'][id_attacker]
        print(f"Init attacker with real id: {id_client} and attacker id: {id_attacker} and pattern: {poison_pattern}")

      client = FlClient(id_client, self.train_loaders[id_client], self.test_loader, self.params, poison_pattern, target_label)
      server.add_client(client)
      # time.sleep(0.2)
      # print(f"Done data id: {id_client}")
    # import IPython; IPython.embed(); exit(0)

    print(f"Done loaded data of {len(server.clients)} clients")
    # import IPython; IPython.embed(); exit(0)
    num_rounds = self.params['epochs']
    # self.start_epoch: 201
    save_wandb = self.params.get('save_wandb', False)

    wandb_dict = server.test_all()

    if save_wandb:
      wandb.init(project="neurips24-nba",
        entity="mtuann",
        group=f"{self.params['group_exp_name']}",
        name=f"{self.params['wandb_exp_name']}")
      wandb.log(wandb_dict, step=self.start_epoch - 1)

    for epoch in range(self.start_epoch, num_rounds + 1, 1):
    # for epoch in range(314, 341, 1):
      print(f"Communication round: {epoch}/ {num_rounds}")
      clients_round = self.get_client_by_round(epoch)
      print(f"At communication round: {epoch} participants: {clients_round}")
      server.train(clients_round)
      wandb_dict = server.test_all()
      if save_wandb:
        wandb.log(wandb_dict, step=epoch)

    return server.get_model()

  # CIFAR-10 dataset
  transform = transforms.Compose([ transforms.ToTensor(),
                                   transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))])

  train_data = datasets.CIFAR10('./data', train=True, download=True, transform=transform)
  test_data = datasets.CIFAR10('./data', train=False, download=True, transform=transform)

  print(len(train_data), len(test_data))

  # statistic about number of samples in each class
  train_stat = {}
  for data, label in train_data:
    if label not in train_stat:
      train_stat[label] = 0
    train_stat[label] += 1
  print(f"Train stat: {train_stat}")

  test_stat = {}
  for data, label in test_data:
    if label not in test_stat:
      test_stat[label] = 0
    test_stat[label] += 1
  print(f"Test stat: {test_stat}")

  # divide the dataset into classes, each with a unique 'label'
  ds_classes = {}
  for i, (_, label) in enumerate(test_data):
    ds_classes.setdefault(label, []).append(i)

  num_clients = 10
  client_train_data = torch.utils.data.random_split(train_data, [len(train_data) // num_clients] * num_clients)
  client_test_data = torch.utils.data.random_split(test_data, [len(test_data) // num_clients] * num_clients)

  # stat data of each client
  for idc in range(num_clients):
    print(f"Client number: {idc}")
    data_client = client_train_data[idc]
    stat_client = {}
    for data, label in data_client:
      if label not in stat_client:
        stat_client[label] = 0
      stat_client[label] += 1

    # initialize a server
    flserver = FLServer()
    for idc in range(num_clients):
      client = FLClient(idc, client_train_data[idc], client_test_data[idc])
      flserver.add_client(client)

    global_model = resnet18(weights=None, num_classes = 10).to(device)

    num_com_round = 10
    for id_com_round in range(num_com_round):
      print(f"Training at communication round id: {id_com_round}")
      list_local_models = []
      global_weights = copy.deepcopy(global_model.state_dict())

      for key in global_weights.keys():
        global_weights[key] = torch.zeros_like(global_weights[key].to(torch.float32))

      for flclient in flserver.clients:
        client_weights, train_metrics = flclient.train(copy.deepcopy(global_model))
        print(f"Finish training client number {flclient.id} with metrics: {train_metrics}")

      # Aggregation step here by FedAvg -> update the global weights by client weights' average update
        for _, key in enumerate(global_weights.keys()):
          update_key = client_weights[key] / num_clients
          global_weights[key].add_(update_key)
      global_model.load_state_dict(global_weights)
      flserver.test(global_model)

      print('*'*100)

if _name_ == '_main_':
  # set fixed random seed
  random_seed = 42
  torch.manual_speed(random_seed)
  torch.cuda.manual_seed_all(random_seed)

  helper = Helper()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# 50000 10000
# Train stat: {6: 5000, 9: 5000, 4: 5000, 1: 5000, 2: 5000, 7: 5000, 8: 5000, 3: 5000, 5: 5000, 0: 5000}
# Test stat: {3: 1000, 8: 1000, 0: 1000, 6: 1000, 1: 1000, 9: 1000, 5: 1000, 7: 1000, 4: 1000, 2: 1000}
# Client number: 0
# Training at communication round id: 0
# Finish training client number: 0 with metrics: {'loss': 2.2467396461486815, 'accuracy': 19.0, '#data': 5000, 'correct': 950}
# Finish training client number: 1 with metrics: {'loss': 2.2553478733062744, 'accuracy': 17.9, '#data': 5000, 'correct': 895}
# Finish training client number: 2 with metrics: {'loss': 2.252340563583374, 'accuracy': 17.5, '#data': 5000, 'correct': 875}
# Finish training client number: 3 with metrics: {'loss': 2.262229895782471, 'accuracy': 17.6, '#data': 5000, 'correct': 880}
# Finish training client number: 4 with metrics: {'loss': 2.2640417015075682, 'accuracy': 16.94, '#data': 5000, 'correct': 847}
# Finish training client number: 5 with metrics: {'loss': 2.259457862472534, 'accuracy': 17.24, '#data': 5000, 'correct': 862}
# Finish training client number: 6 with metrics: {'loss': 2.2336691097259522, 'accuracy': 19.42, '#data': 5000, 'correct': 971}
# Finish training client number: 7 with metrics: {'loss': 2.2420773109436034, 'accuracy': 17.54, '#data': 5000, 'correct': 877}
# Finish training client number: 8 with metrics: {'loss': 2.2416112701416018, 'accuracy': 17.6, '#data': 5000, 'correct': 880}
# Finish training client number: 9 with metrics: {'loss': 2.25961415309906, 'accuracy': 17.72, '#data': 5000, 'correct': 886}
# [{'id': 0, 'loss': 2.2050903663635255, 'accuracy': 17.4, '#data': 1000, 'correct': 174}, {'id': 1, 'loss': 2.213968101501465, 'accuracy': 18.3, '#data': 1000, 'correct': 183}, {'id': 2, 'loss': 2.228797197341919, 'accuracy': 16.4, '#data': 1000, 'correct': 164}, {'id': 3, 'loss': 2.227743886947632, 'accuracy': 15.4, '#data': 1000, 'correct': 154}, {'id': 4, 'loss': 2.222276742935181, 'accuracy': 16.6, '#data': 1000, 'correct': 166}, {'id': 5, 'loss': 2.194670810699463, 'accuracy': 18.1, '#data': 1000, 'correct': 181}, {'id': 6, 'loss': 2.2079406547546387, 'accuracy': 19.1, '#data': 1000, 'correct': 191}, {'id': 7, 'loss': 2.2413508987426756, 'accuracy': 16.0, '#data': 1000, 'correct': 160}, {'id': 8, 'loss': 2.236101963043213, 'accuracy': 15.5, '#data': 1000, 'correct': 155}, {'id': 9, 'loss': 2.21037428855896, 'accuracy': 16.4, '#data': 1000, 'correct': 164}]
# ****************************************************************************************************
# Training at communication round id: 1
# Finish training client number: 0 with metrics: {'loss': 2.0322756248474123, 'accuracy': 25.8, '#data': 5000, 'correct': 1290}
# Finish training client number: 1 with metrics: {'loss': 2.0134097034454346, 'accuracy': 25.86, '#data': 5000, 'correct': 1293}
# Finish training client number: 2 with metrics: {'loss': 2.0387481452941896, 'accuracy': 25.3, '#data': 5000, 'correct': 1265}
# Finish training client number: 3 with metrics: {'loss': 2.0305850458145143, 'accuracy': 25.58, '#data': 5000, 'correct': 1279}
# Finish training client number: 4 with metrics: {'loss': 2.0440648427963257, 'accuracy': 25.0, '#data': 5000, 'correct': 1250}
# Finish training client number: 5 with metrics: {'loss': 2.042234895706177, 'accuracy': 25.42, '#data': 5000, 'correct': 1271}
# Finish training client number: 6 with metrics: {'loss': 2.008684247970581, 'accuracy': 26.38, '#data': 5000, 'correct': 1319}
# Finish training client number: 7 with metrics: {'loss': 2.062789994812012, 'accuracy': 24.12, '#data': 5000, 'correct': 1206}
# Finish training client number: 8 with metrics: {'loss': 2.0356837184906005, 'accuracy': 25.74, '#data': 5000, 'correct': 1287}
# Finish training client number: 9 with metrics: {'loss': 2.044921856880188, 'accuracy': 24.78, '#data': 5000, 'correct': 1239}
# [{'id': 0, 'loss': 1.930939003944397, 'accuracy': 29.2, '#data': 1000, 'correct': 292}, {'id': 1, 'loss': 1.9674640445709228, 'accuracy': 27.6, '#data': 1000, 'correct': 276}, {'id': 2, 'loss': 1.981999994277954, 'accuracy': 26.3, '#data': 1000, 'correct': 263}, {'id': 3, 'loss': 1.9811232814788817, 'accuracy': 27.8, '#data': 1000, 'correct': 278}, {'id': 4, 'loss': 1.976516944885254, 'accuracy': 25.8, '#data': 1000, 'correct': 258}, {'id': 5, 'loss': 1.953972719192505, 'accuracy': 27.5, '#data': 1000, 'correct': 275}, {'id': 6, 'loss': 1.9755587692260743, 'accuracy': 26.3, '#data': 1000, 'correct': 263}, {'id': 7, 'loss': 1.9716489477157593, 'accuracy': 27.2, '#data': 1000, 'correct': 272}, {'id': 8, 'loss': 1.9673500127792358, 'accuracy': 26.1, '#data': 1000, 'correct': 261}, {'id': 9, 'loss': 1.967288579940796, 'accuracy': 26.3, '#data': 1000, 'correct': 263}]
# ****************************************************************************************************
# Training at communication round id: 2
# Finish training client number: 0 with metrics: {'loss': 1.8797175985336303, 'accuracy': 31.44, '#data': 5000, 'correct': 1572}
# Finish training client number: 1 with metrics: {'loss': 1.8792611660003662, 'accuracy': 30.16, '#data': 5000, 'correct': 1508}
# Finish training client number: 2 with metrics: {'loss': 1.8885428537368774, 'accuracy': 30.88, '#data': 5000, 'correct': 1544}
# Finish training client number: 3 with metrics: {'loss': 1.8891735641479492, 'accuracy': 30.52, '#data': 5000, 'correct': 1526}
# Finish training client number: 4 with metrics: {'loss': 1.8984930545806884, 'accuracy': 30.6, '#data': 5000, 'correct': 1530}
# Finish training client number: 5 with metrics: {'loss': 1.8789297328948975, 'accuracy': 31.3, '#data': 5000, 'correct': 1565}
# Finish training client number: 6 with metrics: {'loss': 1.8568805572509766, 'accuracy': 32.62, '#data': 5000, 'correct': 1631}
# Finish training client number: 7 with metrics: {'loss': 1.8887834226608275, 'accuracy': 31.14, '#data': 5000, 'correct': 1557}
# Finish training client number: 8 with metrics: {'loss': 1.8972061058044434, 'accuracy': 29.96, '#data': 5000, 'correct': 1498}
# Finish training client number: 9 with metrics: {'loss': 1.8789715543746948, 'accuracy': 31.04, '#data': 5000, 'correct': 1552}
# [{'id': 0, 'loss': 1.8037188291549682, 'accuracy': 33.5, '#data': 1000, 'correct': 335}, {'id': 1, 'loss': 1.824826452255249, 'accuracy': 33.6, '#data': 1000, 'correct': 336}, {'id': 2, 'loss': 1.8204033002853393, 'accuracy': 32.8, '#data': 1000, 'correct': 328}, {'id': 3, 'loss': 1.813784207344055, 'accuracy': 33.6, '#data': 1000, 'correct': 336}, {'id': 4, 'loss': 1.8268361101150512, 'accuracy': 31.4, '#data': 1000, 'correct': 314}, {'id': 5, 'loss': 1.7997153120040894, 'accuracy': 33.2, '#data': 1000, 'correct': 332}, {'id': 6, 'loss': 1.847896152496338, 'accuracy': 32.1, '#data': 1000, 'correct': 321}, {'id': 7, 'loss': 1.8388146924972535, 'accuracy': 34.3, '#data': 1000, 'correct': 343}, {'id': 8, 'loss': 1.8157501916885377, 'accuracy': 33.8, '#data': 1000, 'correct': 338}, {'id': 9, 'loss': 1.8332178449630738, 'accuracy': 33.0, '#data': 1000, 'correct': 330}]
# ****************************************************************************************************
# Training at communication round id: 3
# Finish training client number: 0 with metrics: {'loss': 1.77193346118927, 'accuracy': 35.08, '#data': 5000, 'correct': 1754}
# Finish training client number: 1 with metrics: {'loss': 1.7661179489135743, 'accuracy': 35.16, '#data': 5000, 'correct': 1758}
# Finish training client number: 2 with metrics: {'loss': 1.7713755964279174, 'accuracy': 36.04, '#data': 5000, 'correct': 1802}
# Finish training client number: 3 with metrics: {'loss': 1.777438042831421, 'accuracy': 35.32, '#data': 5000, 'correct': 1766}
# Finish training client number: 4 with metrics: {'loss': 1.7990130178451538, 'accuracy': 34.02, '#data': 5000, 'correct': 1701}
# Finish training client number: 5 with metrics: {'loss': 1.7761115114212036, 'accuracy': 35.2, '#data': 5000, 'correct': 1760}
# Finish training client number: 6 with metrics: {'loss': 1.740968296432495, 'accuracy': 37.0, '#data': 5000, 'correct': 1850}
# Finish training client number: 7 with metrics: {'loss': 1.7981209255218507, 'accuracy': 33.06, '#data': 5000, 'correct': 1653}
# Finish training client number: 8 with metrics: {'loss': 1.787956251525879, 'accuracy': 34.58, '#data': 5000, 'correct': 1729}
# Finish training client number: 9 with metrics: {'loss': 1.7745598445892334, 'accuracy': 35.54, '#data': 5000, 'correct': 1777}
# [{'id': 0, 'loss': 1.6997132511138917, 'accuracy': 38.9, '#data': 1000, 'correct': 389}, {'id': 1, 'loss': 1.7213365907669067, 'accuracy': 35.9, '#data': 1000, 'correct': 359}, {'id': 2, 'loss': 1.720306402206421, 'accuracy': 35.5, '#data': 1000, 'correct': 355}, {'id': 3, 'loss': 1.7091149396896361, 'accuracy': 36.7, '#data': 1000, 'correct': 367}, {'id': 4, 'loss': 1.7557532148361206, 'accuracy': 34.1, '#data': 1000, 'correct': 341}, {'id': 5, 'loss': 1.6983975572586059, 'accuracy': 35.8, '#data': 1000, 'correct': 358}, {'id': 6, 'loss': 1.7741152248382568, 'accuracy': 34.1, '#data': 1000, 'correct': 341}, {'id': 7, 'loss': 1.752844542503357, 'accuracy': 37.4, '#data': 1000, 'correct': 374}, {'id': 8, 'loss': 1.7004551362991334, 'accuracy': 36.8, '#data': 1000, 'correct': 368}, {'id': 9, 'loss': 1.7451062679290772, 'accuracy': 36.0, '#data': 1000, 'correct': 360}]
# ****************************************************************************************************
# Training at communication round id: 4
# Finish training client number: 0 with metrics: {'loss': 1.6911886421203612, 'accuracy': 38.44, '#data': 5000, 'correct': 1922}
# Finish training client number: 1 with metrics: {'loss': 1.6974129947662353, 'accuracy': 37.3, '#data': 5000, 'correct': 1865}
# Finish training client number: 2 with metrics: {'loss': 1.7075365354537964, 'accuracy': 37.7, '#data': 5000, 'correct': 1885}
# Finish training client number: 3 with metrics: {'loss': 1.7034431718826295, 'accuracy': 37.84, '#data': 5000, 'correct': 1892}
# Finish training client number: 4 with metrics: {'loss': 1.7119726821899415, 'accuracy': 36.7, '#data': 5000, 'correct': 1835}
# Finish training client number: 5 with metrics: {'loss': 1.6924786684036255, 'accuracy': 37.12, '#data': 5000, 'correct': 1856}
# Finish training client number: 6 with metrics: {'loss': 1.660458403778076, 'accuracy': 39.06, '#data': 5000, 'correct': 1953}
# Finish training client number: 7 with metrics: {'loss': 1.7238049018859862, 'accuracy': 35.82, '#data': 5000, 'correct': 1791}
# Finish training client number: 8 with metrics: {'loss': 1.6980314195632935, 'accuracy': 37.78, '#data': 5000, 'correct': 1889}
# Finish training client number: 9 with metrics: {'loss': 1.687024568939209, 'accuracy': 38.98, '#data': 5000, 'correct': 1949}
# [{'id': 0, 'loss': 1.635210573196411, 'accuracy': 41.1, '#data': 1000, 'correct': 411}, {'id': 1, 'loss': 1.6398722314834595, 'accuracy': 38.8, '#data': 1000, 'correct': 388}, {'id': 2, 'loss': 1.6502660808563232, 'accuracy': 38.0, '#data': 1000, 'correct': 380}, {'id': 3, 'loss': 1.6440808162689209, 'accuracy': 37.8, '#data': 1000, 'correct': 378}, {'id': 4, 'loss': 1.6812258071899413, 'accuracy': 37.3, '#data': 1000, 'correct': 373}, {'id': 5, 'loss': 1.628195927619934, 'accuracy': 38.7, '#data': 1000, 'correct': 387}, {'id': 6, 'loss': 1.6920781230926514, 'accuracy': 35.7, '#data': 1000, 'correct': 357}, {'id': 7, 'loss': 1.680022611618042, 'accuracy': 39.6, '#data': 1000, 'correct': 396}, {'id': 8, 'loss': 1.6367325134277344, 'accuracy': 38.6, '#data': 1000, 'correct': 386}, {'id': 9, 'loss': 1.6808377408981323, 'accuracy': 38.9, '#data': 1000, 'correct': 389}]
# ****************************************************************************************************
# Training at communication round id: 5
# Finish training client number: 0 with metrics: {'loss': 1.6272842920303345, 'accuracy': 40.9, '#data': 5000, 'correct': 2045}
# Finish training client number: 1 with metrics: {'loss': 1.6264120344161987, 'accuracy': 40.62, '#data': 5000, 'correct': 2031}
# Finish training client number: 2 with metrics: {'loss': 1.6450540956497193, 'accuracy': 40.1, '#data': 5000, 'correct': 2005}
# Finish training client number: 3 with metrics: {'loss': 1.6516952436447143, 'accuracy': 38.98, '#data': 5000, 'correct': 1949}
# Finish training client number: 4 with metrics: {'loss': 1.6471564037322999, 'accuracy': 40.02, '#data': 5000, 'correct': 2001}
# Finish training client number: 5 with metrics: {'loss': 1.6200878435134887, 'accuracy': 40.1, '#data': 5000, 'correct': 2005}
# Finish training client number: 6 with metrics: {'loss': 1.6001604698181153, 'accuracy': 41.58, '#data': 5000, 'correct': 2079}
# Finish training client number: 7 with metrics: {'loss': 1.6685869579315185, 'accuracy': 38.96, '#data': 5000, 'correct': 1948}
